# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshata-Varude/Hotel-Booking-Analysis-EDA/blob/main/Hotel_Booking_Analysis_EDA_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **"Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name  -** Akshata Vivek Varude

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Hotel business is a profitable yet very volatile business segment. It depends on many criteria like hotel location, business seasons, customer segment, multiple modes of booking , etc. Since the COVID-19 pandemic has imposed many limits on travel and tourism, the hotel sector, a key driver of the global economy’s growth, has suffered greatly.
#
# Now many business leaders and entrepreneurs are adopting data analytics as technology advances. Data Analytics for hotel management can help in studying demand and customer behavior to boost overall profits.
#
# By applying Exploratory Data Analysis principles and feature engineering, this study aims to explore merits of analysis on Hotels dataset that governs bookings and can help in increasing customer base. Secondary objective is to help the customers in deciding the best period to visit places while availing low accommodation cost benefits.
#
# In this project we were provided a dataset containing booking information about two types of hotels and various other related booking criteria. This dataset contains total rows 119390 and 32 columns. This dataset contains many features like hotel: Name of hotel ( City or Resort), is_canceled: Whether the booking is canceled or not, arrival_date: date, months, year, week of arrival, stays_in_weekend_nights, stays_in_week_nights, number of members adults, childerns, babies, Meal, country of customer belongs, market_segment: What segment via booking was made and for what purpose, distribution_channel: Via which medium booking was made, is_repeated_guest: Whether the customer has made any booking before , and many booking related features.
#
# First step of the approach involved Data Exploration and Inspection over the raw data. Second step involved Data Cleaning by handling null values, dropping irrelevant columns and rows, removing duplicate values that can help in better decision support. Final step involved performing a comprehensive data analysis over clean data to analyze the factors that affect hotel bookings and creating Data Visualization for the same.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
#
# Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Business Objective**
#
# The dataset contains booking information for two different hotels. One is City Hotel and another is Resort Hotel along with information on various booking criteria such as booking season, time of booking, length of stay, number of adults, children and babies, parking spaces, pricing data, market segment and many more.
#
# There are two main objective for hotel booking analysis manager approch and customer approch:
# First objective for manager to increase customer, to increase profit, and how they can add other facilities to attract customer.
# Secondary objective is help the customers in deciding best period to visit places while availing low accommodation cost benefits.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load dataset
# mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Adding dataset file path
dataset_file_path = '/content/drive/My Drive/AlmaBetter Projects/Hotel Bookings.csv'
df = pd.read_csv(dataset_file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# checking first five rows of data
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# checking last five rows of data
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Data set rows and columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# There are 119390 rows and 32 coloumns.

# %%
# information about columns name
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# duplicate value count
df.duplicated().value_counts() #true means duplicate values conut
# Out:
# False    87396
# True     31994
# dtype: int64

# %% [markdown]
# From above results it is shown that there are 31994 duplicate values are present in dataset of data type int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# missing values/null value count
df.isnull().sum().sort_values(ascending = False)
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100, 2)
# Out:
# company                           93.98
# agent                             13.95
# country                            0.52
# children                           0.00
# reserved_room_type                 0.00
# assigned_room_type                 0.00
# booking_changes                    0.00
# deposit_type                       0.00
# hotel                              0.00
# previous_cancellations             0.00
# days_in_waiting_list               0.00
# customer_type                      0.00
# adr                                0.00
# required_car_parking_spaces        0.00
# total_of_special_requests          0.00
# reservation_status                 0.00
# previous_bookings_not_canceled     0.00
# is_repeated_guest                  0.00
# is_canceled                        0.00
# distribution_channel               0.00
# market_segment                     0.00
# meal                               0.00
# babies                             0.00
# ...

# %%
# Visualizing the missing/null values through heatmap
plt.figure(figsize=(20, 5))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False,cmap='inferno')
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In dataset there are 119390 rows and 32 columns.
# We check the duplicate values there are 31994 duplicte rows.
#
# We checked null values in our dataset from that we found that there are null values in columns - company, agent, country and children.
# A) For company column it contains 94% null data.
#
# B) For agent it contains 13.95% null data, so assuming those rooms were booked without any agents.
#
# C) For country it contains 0.52% null data , so assuming tourist belong to country other than available list.
#
# D) For children there are only 4 null value count, so assuming 0 children in that family.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# dataset describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
#dataset column
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Description of individual Variable. There are 32 different variables.
#
# The columns and the data it represents are listed below:
#
# 1. hotel : Name of the hotel (Resort Hotel or City Hotel)
#
# 2. is_canceled : If the booking was canceled (1) or not (0)
#
# 3. lead_time: Number of days before the actual arrival of the guests
#
# 4. arrival_date_year : Year of arrival date
#
# 5. arrival_date_month : Month of month arrival date
#
# 6. arrival_date_week_number : Week number of year for arrival date
#
# 7. arrival_date_day_of_month : Day of arrival date
#
# 8. stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
#
# 9. stays_in_week_nights : Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
# 10. adults : Number of adults among guests
#
# 11. children : Number of children among guests
#
# 12. babies : Number of babies among guests
#
# 13. meal : Type of meal booked
#
# 14. country : Country of guests
#
# 15. market_segment : Designation of market segment
#
# 16. distribution_channel : Name of booking distribution channel
#
# 17. is_repeated_guest : If the booking was from a repeated guest (1) or not (0)
#
# 18. previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19. previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20. reserved_room_type : Code of room type reserved
#
# 21. assigned_room_type : Code of room type assigned
#
# 22. booking_changes : Number of changes/amendments made to the booking
#
# 23. deposit_type : Type of the deposit made by the guest
#
# 24. agent : ID of travel agent who made the booking
#
# 25. company : ID of the company that made the booking
#
# 26. days_in_waiting_list : Number of days the booking was in the waiting list
#
# 27. customer_type : Type of customer, assuming one of four categories
#
# 28. adr : Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29. required_car_parking_spaces : Number of car parking spaces required by the customer
#
# 30. total_of_special_requests : Number of special requests made by the customer
#
# 31. reservation_status : Reservation status (Canceled, Check-Out or No-Show)
#
# 32. reservation_status_date : Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# check unique values for each variable
for i in df.columns:
  a=df[i].unique()
  print(f'{i}={a}')
# Out:
# hotel=['Resort Hotel' 'City Hotel']
# is_canceled=[0 1]
# lead_time=[342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# #### Removing Duplicate Value

# %%
# Write your code to make your dataset analysis ready.
# Remove duplicates
df = df.drop_duplicates()
df.shape                  # after removing duplicate rows
# Out:
# (87396, 32)

# %% [markdown]
# We check the duplicate values there are 31994 duplicte rows. After removing duplicate rows there are 87396 rows and 32 columns.

# %% [markdown]
# #### Working on null values

# %% [markdown]
# We checked null values in our dataset from that we found that there are null values in columns - company, agent, country and children.
#
# Let's take the comapny column
#
# A) For company column it contains 94% null data.

# %%
# For company column it contains 94% null data, so it is better to drop the company column.
df.drop(['company'],axis = 1,inplace = True)

# %%
# after removing company column there are 31 columns remaining.
df.shape
# Out:
# (87396, 31)

# %% [markdown]
# Let's take agent column.
#
# B) For agent column it contains 13.95% null data, so assuming those rooms were booked without any agents.

# %%
df['agent'].mode()
# In missing value / null value we see that for agent column minimum number of null values are present. So we replace null values with mode value.
df['agent'].fillna(0, inplace = True)

# %%
df['agent'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Let's  take country column.
#
# C) For country it contains 0.52% null data , so assuming tourist belong to country other than available list.

# %%
#from above we see that percentage of null values in country column is very less so we replaced the null values by Other
df['country'].fillna('other', inplace = True)

# %%
df['country'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Let's take children column.
#
# D) For children there are only 4 null value count, so assuming 0 children in that family.

# %%
#from above we see that children column has very less null vaues therefore fill null values with 0
df['children'].fillna(value=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# #### Change the dtype of some variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#from above info it is seen that the children column and agent column has float value which is converted into int64 for our requirnment
df[['children','agent']] = df[['children','agent']].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-7-2ce50d3c67f5> in <cell line: 2>()
#       1 #from above info it is seen that the children column and agent column has float value which is converted into int64 for our requirnment
# ----> 2 df[['children','agent']] = df[['children','agent']].astype('int64')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
# ...

# %% [markdown]
# #### Creating the new columns for our requirement

# %%
# create new column for total number of guest.
df['total_guest'] = df['adults'] + df['children'] + df['babies']

# %%
# create new column for total stays in nights
df['total_stays_in_nights'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']

# %%
# create new column for revenue of hotel
df['revenue'] = df['total_stays_in_nights'] * df['adr']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Converting Columns As Our Requirement

# %%
#for our understanding replace the is_calceled column value of(0,1) with 'not canceled' and 'canceled'
df['is_canceled'] = df['is_canceled'].replace([0,1],['not canceled','is canceled'])

# %%
#for our understamding replace the is_repeated_guest column of value (0,1) with the 'repeat' and 'not repeat'
df['is_repeated_guest'] = df['is_repeated_guest'].replace([0,1], ['not repeated','repeated'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.   Removed duplicate value :
# There are 31994 duplicte rows. After removing duplicate rows there are 87396 rows and 32 columns.
#
# 2.   Worked on null value : So we have null values in columns - company, agent, country and children.
#
#       A) For company I will drop the column because it contains 94% null data.
#
#       B) For agent I will fill the null values with 0 assuming those rooms were booked without any agents.
#
#       C) For country I will fill the null values with object 'Others', assuming tourist belong to country other than available list.
#
#       D) For children, I will fill the null values with 0, assuming 0 children in that family.
#
# 3.   Changed dtype of some variable : The children column and agent column has float value which is converted into int64 for our requirnment.
#
# 4. Created new column for our requirement :
#
#     A) Created new column for **Total_Number_Of_guests** stayed in one room. There are three different column for total children, total babies, total adults. So we combine these three column in one column.
#
#     B) Created new column for **Total_Stays_In_Nights**. There are two differnt column for stays in week nights and stays in weekend nights, so we combined both column for total stays in nights.
#
#     c) Created new column for **Revenue**. For calculating revenue of hotel we multiplied total stays in nights column with adr column.
# 5. Changed columns for our requirement :
#
#   *   For our understanding replace the is_calceled column value of(0,1) with 'not canceled' and 'canceled'
#   *   For our understamding replace the is_repeated_guest column of value (0,1) with the 'repeat' and 'not repeat'
#
# '

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# **EDA (Expolatory Data Analysis)**

# %% [markdown]
# #### Chart - 1

# %%
# Chart 1: visulisation code

#Fetching the unique hotel count
booking_data = df['hotel'].value_counts()
booking_data
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
# Plotting pie chart of unique hotel booking

x_axis = booking_data.plot.pie(figsize = (12,8), fontsize = 15, autopct = '%5.1f%%', shadow = True, explode = [0.04,0.04] )
x_axis.set_title('Booking percentage in each hotel', fontsize=19)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is graph for showing the proportions of categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   City hotels occupy 66.4% and resort hotels occupy 33.6% of customers.
# *   From the above results, we can say that there is a majority of guests in city hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It will help business owners in deciding on which hotel type to invest their money in to gain maximum financial leverage.

# %% [markdown]
# #### Chart - 2

# %%
# chart 2: visulisation code

# Counting the guests from various countries.
country_data = df['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]


# Visualizing by plotting the graph
plt.figure(figsize=(10,5))
sns.barplot(x=country_data['country'],y=country_data['count of guests'])
plt.xlabel('Country',fontsize=20)
plt.ylabel('Number of guests',fontsize=20)
plt.title("Number of guests from diffrent Countries",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot shows catergorical data as rectangular bars with the height of bars proportional to the value they represent. It is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From plotted bar plot, it is shown that most of guest visiting these City hotels and Resort hotels are from Portugal and other European countries namely Britain, France, Spain and Germany.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can do more advertising & can provide attractive offers to Portugal guests to enhance the customer volume

# %% [markdown]
# #### Chart - 3

# %%
# Chart 3: visulisation code

# Setting the plot size
plt.figure(figsize=(10,6))

# Plotting with countplot
list1=['hotel', 'arrival_date_year', 'arrival_date_month','arrival_date_day_of_month']
arrival_overview = df[list1]
sns.countplot(data =arrival_overview, x = 'arrival_date_year', hue = 'hotel')
plt.title('Customer arrival by year',fontsize=20)
plt.xlabel('Years', fontsize = 14)
plt.ylabel('Number of bookings',fontsize = 14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see that 2016 was the year where number of hotel booking was highest followed by total bookings in 2017 and 2015.
#
# Overall City hotel had the highest number of bookings compared with Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel owners should divert more of their resources on City hotels to maximise their profits, at the same time can try to attend to existing customers of Resort hotel.

# %% [markdown]
# #### Chart - 4

# %%
# Chart 4 :

# groupby arrival_date_month and taking the hotel count
bookings_by_months_data = df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Creating list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_data['arrival_date_month'] = pd.Categorical(bookings_by_months_data['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_data = bookings_by_months_data.sort_values('arrival_date_month')

bookings_by_months_data
# Out:
#    arrival_date_month  Counts
# 4             January    5929
# 3            February    8068
# 7               March    9794
# 0               April   11089
# 8                 May   11791
# 6                June   10939
# 5                July   12661
# 1              August   13877
# 11          September   10508
# 10            October   11160
# 9            November    6794
# 2            December    6780

# %%
# Visulisation code

# Setting plot size
plt.figure(figsize=(15,5))

# Plotting lineplot on x-months & y-booking counts
sns.lineplot(x=bookings_by_months_data['arrival_date_month'],y=bookings_by_months_data['Counts'])

# Setting title for the plot
plt.title('Number of bookings across each month',fontsize=25)
# Setting x label
plt.xlabel('Month',fontsize=20)
# Setting y label
plt.ylabel('Number of bookings',fontsize=20)
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line Plot is used to express a relationship between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Peak visiting season is from mid June to August.
# Off season is from November to February.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights can be used by hotel owners to apply dynamic pricing to their packages. In peak seasons, price may be kept higher. For example, during summer holidays from June to September, prices may be kept higher, while during off season (Winter months) from November to February, price may be kept lower.

# %% [markdown]
# #### Chart - 5

# %%
# Chart 5:

# Return highest bookings made by agents
highest_bookings_by_agent = df.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

# As agent 0 was a NAN value, we replaced it with 0 which indicates no bookings. So decided to drop.
highest_bookings_by_agent.drop(highest_bookings_by_agent[highest_bookings_by_agent['agent']==0].index,inplace=True)

# Taking into consideration top 10 agents
top_ten_highest_bookings_by_agent = highest_bookings_by_agent[:10]

top_ten_highest_bookings_by_agent
# Out:
#      agent  Most_Bookings
# 8      9.0          31961
# 173  240.0          13922
# 0      1.0           7191
# 13    14.0           3640
# 6      7.0           3539
# 5      6.0           3290
# 182  250.0           2870
# 174  241.0           1721
# 26    28.0           1666
# 7      8.0           1514

# %%
# Visulisation code

# Plotting the graph

plt.figure(figsize=(15,5))
sns.barplot(x=top_ten_highest_bookings_by_agent['agent'],y=top_ten_highest_bookings_by_agent['Most_Bookings'],order=top_ten_highest_bookings_by_agent['agent'])
plt.xlabel('Agent No',fontsize=18)
plt.ylabel('Number of Bookings',fontsize=18)
plt.title("Most Bookings Made by the agent",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot shows catergorical data as rectangular bars with the height of bars proportional to the value they represent. It is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Agent ID No. 9.0 made most of the bookings, followed by 240.0

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above insight, hotel owners may incentivise both the top two agents, while at the same time motivate agents.

# %% [markdown]
# #### Chart - 6

# %%
# Visulisation code
# Setting plotsize
plt.figure(figsize=(15,4))

# Plotting
sns.countplot(x=df['assigned_room_type'],order=df['assigned_room_type'].value_counts().index)
#  setting xlabel for the plot
plt.xlabel('Room Type',fontsize=15)
# setting y label for the plot
plt.ylabel('Count of Room Type',fontsize=15)
# setting title for the plot
plt.title("Most preferred Room type",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most preferred Room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most demanded room type is A, followed by D and E.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotels should increase the number of room types A to maximise revenue.

# %% [markdown]
# #### Chart - 7

# %%
# visulisation code
# Plotting the chart of preferred meal type
plt.figure(figsize=(15,5))
sns.countplot(x=df['meal'])
plt.xlabel('Meal Type',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title("Preferred Meal Type",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# Types of meal in hotels:
#
# *   BB - (Bed and Breakfast)
# *   HB- (Half Board)
# *   FB- (Full Board)
# *   SC- (Self Catering)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most preferred meal type by the guests is BB(Bed and Breakfast)
#
# HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, with the gained insights hotel owner may be able to switch to dynamic pricing models for their meal plans. Those meal plan with the highest demand can be charged little bit higher with added features, while those with less demand can be charged a bit lower, to attract the customers to avail that meal type.

# %% [markdown]
# #### Chart - 8

# %%
# finding average adr for hotels
average_adr = df.groupby('hotel').adr.mean()
average_adr
# Out:
# hotel
# City Hotel      105.304465
# Resort Hotel     94.952930
# Name: adr, dtype: float64

# %%
# Visulisation code
plt.subplots(figsize=(10,5))
average_adr.plot(kind='barh',color=('r','b'))
plt.xlabel('Average ADR',fontsize= 15)
plt.ylabel('Hotel Type',fontsize=15)
plt.title("Average ADR of Hotel", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Average ADR of Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see the average ADR of City hotel is higher than Resort hotel, so the profit and revenue will be higher for city hotel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here, we can do more advertising for City hotel to get more customer, which result higher profit

# %% [markdown]
# #### Chart - 9

# %%
# Visulisation code
# Groupby arrival month and hotel
bookings_by_months_df = df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
# Creating month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# It will take the order of the month list in the df along with values
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# Sorting of month values
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   82.628986
# 9             January  Resort Hotel   49.461883
# 6            February    City Hotel   85.088278
# 7            February  Resort Hotel   55.171930
# 15              March  Resort Hotel   57.520147
# 14              March    City Hotel   92.643116
# 0               April    City Hotel  111.251838
# 1               April  Resort Hotel   77.849496
# 17                May  Resort Hotel   78.758134
# 16                May    City Hotel  121.638560
# 13               June  Resort Hotel  110.444749
# 12               June    City Hotel  119.074341
# 11               July  Resort Hotel  155.181299
# 10               July    City Hotel  110.734292
# 3              August  Resort Hotel  186.790574
# 2              August    City Hotel  114.680455
# 22          September    City Hotel  110.004661
# 23          September  Resort Hotel   93.252030
# 20            October    City Hotel   99.974498
# ...

# %%
# Setting plot size and plotting the line chart
plt.figure(figsize=(15,5))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# Setting the lables
plt.title('ADR across each month',fontsize=20)
plt.xlabel('Month',fontsize=15)
plt.ylabel('ADR',fontsize=15)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is a type of chart used to show information that changes over time. Line charts are used to track changes over short and long periods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For Resort Hotels the ADR is high in the months of June, July and August as compared to City Hotels. May be Customers wants to spend their Summer vacation in Resorts Hotels.
#
# The best time for guests to visit Resort or City hotels is January, February, March, April, October, November and December as the average daily rate in these months is very low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, with the above insight, hotel owners may try to attract the customers in off season with low prices to fill their rooms. Since in peak months, resort hotel is generating a lot of revenue, hotel owners may divert their resources for that time period towards resort hotels.

# %% [markdown]
# #### Chart - 10

# %%
# Visulisation code

# Plotting the pie chart
df['is_canceled'].value_counts().plot.pie(explode=[0.04, 0.04], autopct='%1.1f%%', shadow=True, figsize=(10,7),fontsize=20)
# Setting the title
plt.title("Cancellation and non Cancellation", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Cancellation and non Cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts typically show relative proportions of different categories in a data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 27.5 % of the bookings were cancelled,
# while 72.5% were not cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel owners should try to find out why did the customers, who has booked earlier, went on to cancel the booking. By taking their feedback through voice call or email, companies may know the reason. Accordingly they may change their strategy to counter such scenarios in the future.

# %% [markdown]
# #### Chart - 11

# %%
# Visulisation code

# Repeated guest = 1
# Non repeated guest = 0
# Groupby hotel
repeated_guests_df = df[df['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repated_guests'})



# Setting plot size and plotting barplot
plt.figure(figsize=(10,5))
sns.barplot(x=repeated_guests_df['hotel'],y=repeated_guests_df['number_of_repated_guests'])

# Setting labels
plt.xlabel('Hotel type',fontsize=15)
plt.ylabel('Count of repeated guests',fontsize=15)
plt.title("Most repeated guests for each hotel",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most repeated guests for each hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Resort Hotel has slightly more repeated guests than the City Hotel. It is almost similar for both hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, Since both the hotels have almost similar repeated guests, with city hotel leading with a slight margin, it shows that customers are quite satisfied with the services being offered. Hotel owners should try to retain those customers for a longer period of time.

# %% [markdown]
# #### Chart - 12

# %%
# Visulisation code

# Groupby distribution channel and hotel
bar_chart = df.groupby(['hotel','distribution_channel'])['adr'].count().unstack().transpose().fillna(0)
bar_chart.drop('Undefined',axis =0, inplace = True)

#displaying the bar_chart dataframe
bar_chart
# Out:
# hotel                 City Hotel  Resort Hotel
# distribution_channel
# Corporate                 3408.0        3269.0
# Direct                    6780.0        7865.0
# GDS                        193.0           0.0
# TA/TO                    68945.0       28925.0

# %%
# Plotting bar chart for distribution channel of both hotels by average daily rate
ax =  bar_chart.plot(kind = "barh",figsize=(10,6))
ax.legend(bbox_to_anchor=(1,1))

# Adding the label of the chart
ax.yaxis.set_label_text("Market segment", fontsize = 15)
ax.xaxis.set_label_text("Average daily Rate", fontsize = 15)
ax.set_title("Market segment wise ADR", fontsize = 20)

# Displaying the chart
plt.show()

# %% [markdown]
# Corporate - These are corporate hotel booking companies which makes bookings possible.
#
# GDS - A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live products, price and availability data to travel agents and online booking engines, and allows for automated transactions.
#
# Direct- The bookings which are directly made with the respective hotels.
#
# TA/TO- The bookings which are made through travel agents or tour operators.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart is clear that :
#
# 'Direct' and 'TA/TO' channel has almost equally contributed in ADR in both type of hotels i.e. 'City Hotel' and 'Resort Hotel'. While 'TA/TO' dominates the chart in terms of total ADR.
#
# GDS has slightly contributed in adr in 'City Hotel' type.
#
# Corporate booking channel has also contributed to the ADR.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, Hotel owners should tie up with TA/TO partners, to increase their market share.

# %% [markdown]
# #### Chart - 13

# %%
# Visulisation code
# Plotting a pie chart
df['is_repeated_guest'].value_counts().plot.pie(explode=(0.04,0.04),autopct='%1.1f%%',shadow=True,figsize=(12,8),fontsize=15)
# Creating the title
plt.title(" Percentage of repeated guests",fontsize=20)
# Out:
# Text(0.5, 1.0, ' Percentage of repeated guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts typically show relative proportions of different categories in a data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Repeated guests are very few which only comprise of 3.9 %.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel owners, in order to retain the guests should take feedbacks from them and try to improve upon the services or provide something unique than their competitors.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation heatmap visulisation code
corr_df = df[['lead_time','previous_cancellations', 'previous_bookings_not_canceled', 'total_guest',
                    'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']].corr()
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(corr_df, annot = True, fmt='.2f', annot_kws={'size': 10},  vmax=1, square=True, cmap="YlGnBu")
plt.title('Co-relation of the columns', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmaps was used to find potential relationships between variables and to understand the strength of these relationships.
#
# To understand the relationsip between different numerical values

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Highest corelation value between axis is 39% positive & lowest corelation value between the axis is -9% negative.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Inorder to achieve the business objective I would suggest the client:
#
# To make the price dynamic, introduce offers and packages to attract new customers.
#
# To retain the existing customers and ensure their repetition the client must introduce loyalty points program which can be redeemed by the customers in their next bookings. Amenities such as parking spaces, kids corner, free internet connection can be provided to increase the number of bookings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   Majority (61%) of the guests prefer City Hotel over Resort Hotel.
#
# *   Most of guest visiting these hotels are from European countries namely Portugal, Britain, France, Spain and Germany totaling to 75% of total booking count
# *   2016 observed the highest booking reservations.
# *   From Booking trend it can be inferred that Peak visiting season is from mid June to August because of summer breaks in Europe while November to February is off season because of freezing cold weather throughout Europe.
#
# *   Agent ID No. 9.0 made most of the bookings above 25 thousands.
# *   Hotels should increase the number of room types A to maximise revenue because most demanded room type is A.
#
#
# *   The most preferred meal type by the guests is BB(Bed and Breakfast) and HB- (Half Board) and SC- (Self Catering) are equally preferred. Hotel owner may be able to switch to dynamic pricing models for their meal plans. Those meal plan with the highest demand can be charged little bit higher with added features, while those with less demand can be charged a bit lower, to attract the customers to avail that meal type.
# *  The average ADR of City hotel is higher than Resort hotel, so the profit and revenue will be higher for city hotel. So do more advertising for City hotel to get more customer, which result higher profit
#
#
# *  For Resort Hotels the ADR is high in the months of June, July and August as compared to City Hotels. May be Customers wants to spend their Summer vacation in Resorts Hotels. Hotel owners may try to attract the customers in off season with low prices to fill their rooms. Since in peak months, resort hotel is generating a lot of revenue, hotel owners may divert their resources for that time period towards resort hotels.
#
#
# *  27.5 % of the bookings were cancelled, while 72.5% were not cancelled.
# Hotel owners should try to find out why did the customers, who has booked
# earlier, went on to cancel the booking. By taking their feedback through voice call or email, companies may know the reason. Accordingly they may change their strategy to counter such scenarios in the future.
#
# *   Hotel owners should tie up with TA/TO partners, to increase their market share.
# *   Hotel owners, in order to retain the guests should take feedbacks from them and try to improve upon the services or provide something unique than their competitors.
#
#
#
# *   Highest corelation value between axis is 39% positive & lowest corelation value between the axis is -9% negative.

# %% [markdown]
# # ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
